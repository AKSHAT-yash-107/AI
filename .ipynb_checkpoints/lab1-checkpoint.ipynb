# %%
#sum average
arr=[]
x=int(input("enter array size="))
sum=0
for i in range(x):
    num =int(input("enter numbr for:"))
    arr.append(num)
    sum+=num

print("sum = ",sum, "avg=",sum/x)
# Out:
# enter array size= 44
# enter numbr for: 234
# enter numbr for: 324
# enter numbr for: 4234
# enter numbr for: 2423
# enter numbr for: 4
# enter numbr for: 234
# enter numbr for: 2342
# enter numbr for: 4324
# enter numbr for: 23
# enter numbr for: 534
# enter numbr for:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       4 sum=0
#       5 for i in range(x):
# ----> 6     num =int(input("enter numbr for:"))
#       7     arr.append(num)
#       8     sum+=num
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# cube and square
x=int(input("enter number"))
print("Square-" ,x**2,"cube=",x**3)

# %%
#vowel or not 
ch = input("Enter an alphabet: ").lower()

if ch in ['a', 'e', 'i', 'o', 'u']:
    print(ch, "is a vowel")
else:
    print(ch, "is a consonant")
# Out:
# Enter an alphabet:  a
# a is a vowel

# %%
#second largest
x=int(input("enter number"))
y=int(input("enter number"))
z=int(input("enter number"))
if (x > y and x < z) or (x > z and x < y):
    second = x
elif (y > x and y < z) or (y > z and y < x):
    second = y
else:
    second = z

print("Second largest =", second)
# Out:
# enter number 1 \
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 #second largest
# ----> 2 x=int(input("enter number"))
#       3 y=int(input("enter number"))
#       4 z=int(input("enter number"))
#
# ValueError: invalid literal for int() with base 10: '1 \\'

# %%
#product of 2
x=int(input("enter number"))
y=int(input("enter number"))
print("prod=",x*y)
# Out:
# enter number 2
# enter number 3
# prod= 6
